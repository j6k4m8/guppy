# %%
from generate_show import MacSayFfmpegAudioMaker, OpenAIGuidanceShowGenerator, ShowMaker, AWSPollyAudioMaker

# %%
show_maker = ShowMaker(
    OpenAIGuidanceShowGenerator(
        title="Chopin and Sand",
        show_description="A scholarly interrogation of the relationship between Chopin and George Sand.",
        episode_count=2,
        episode_length_minutes=3,
        openai_key=None,
    ),
    # MacSayFfmpegAudioMaker(check_available=False)
    AWSPollyAudioMaker(aws_profile="kordinglab"),
)

# %%
eps = show_maker.create_show()
# Out:
# <pre style='margin: 0px; padding: 0px; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are a helpful and intelligent lecturer who hosts a podcast series. Your job is to combine the request with your own domain knowledge in order to create a 330 word lecture that is informative and entertaining. You must cover all of the material that the student has in their notes, but you may also add additional information if you believe it will be helpful. You may go longer than 330 words if you need to finish a thought.
#
# At the end of each paragraph, you must put in brackets the total number of words you have generated so far like this. [[132]]
#
# Make sure that the podcast is casual but precise, conversational, and not too dense to follow. When you introduce a new topic, spend some time explaining it. Feel free to use analogies and metaphors, and build a narrative through transition language like &quot;we now know X, let&#x27;s see how that helps us understand Y&quot;.
#
# IMPORTANT: DO NOT include speaker markings like &quot;HOST: &quot;, and DO NOT include timestamps or section/chapter headers like [INTRODUCTION], as this transcript will be read exactly as it is written. If you include these items, you will be punished, as this is NOT correct.
#
# Include a VERY brief introduction and conclusion. The introduction should explain what the lecture is about and why it is important. You may reference other episodes (&quot;recall from Episode 3&quot; or &quot;we&#x27;ll talk more about this in episode 4&quot;) if you need to. The conclusion should summarize the main points of the lecture. The name of the Podcast producer company is Guppy Courses.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>---
# SHOW TITLE: Chopin and Sand
# ALL PREVIOUS EPISODES:
# 1. Episode 1: Introduction: We explore the background and early life of Frédéric Chopin, including his upbringing in Poland and his early musical education.
# 2. Episode 2: Romanticism in Music: We delve into the Romantic era in music and discuss how Chopin&#x27;s compositions embodied the spirit of Romanticism.
# ---
# THIS EPISODE TITLE: Episode 2: Romanticism in Music
# ---
# THIS EPISODE DESCRIPTION: We delve into the Romantic era in music and discuss how Chopin&#x27;s compositions embodied the spirit of Romanticism.
# ---
# THIS EPISODE TRANSCRIPT:
# </div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'>Welcome</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> back</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> to</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> Gu</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'>ppy</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> Courses</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'>,</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> where</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> we</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> dive</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> deep</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> into</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> the</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> world</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> of</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> music</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> and</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> explore</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> its</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> rich</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> history</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'>.</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> In</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> today</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'>&#x27;s</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> episode</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'>,</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> we</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> continue</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> our</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> exploration</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> of</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> the</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> life</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> and</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> works</span><span style='background-color: rgba(0, 165, 0, 0.15); border-radius: 3px;' title='0.0'> of</span><span style='background-color ...
